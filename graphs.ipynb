# %%
import matplotlib.pyplot as plt

# Data for the first model
steps_model1 = [0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 4999]
train_loss_model1 = [2.6962, 1.6796, 1.3363, 1.1942, 1.1087, 1.0230, 0.9260, 0.8073, 0.6774, 0.5621, 0.4624]
val_loss_model1 = [2.6865, 1.6102, 1.3167, 1.2047, 1.1500, 1.1508, 1.1711, 1.2351, 1.3119, 1.4189, 1.5578]

# Data for the second model
steps_model2 = [0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 4999]
train_loss_model2 = [2.8427, 0.8932, 0.7929, 0.7363, 0.7094, 0.6974, 0.6667, 0.6399, 0.6170, 0.5787, 0.5396]
val_loss_model2 = [2.8242, 0.8434, 0.7560, 0.7117, 0.6934, 0.6897, 0.6776, 0.6736, 0.6820, 0.6927, 0.7102]

# Create the plot
plt.figure(figsize=(6,3))

# Plot for the first model
plt.plot(steps_model1, train_loss_model1, label='Pitch-Only Model: Train Loss', marker='o')
plt.plot(steps_model1, val_loss_model1, label='Pitch Only Model- Val Loss', marker='o')

# Plot for the second model
plt.plot(steps_model2, train_loss_model2, label='Pitch +Time Model - Train Loss', marker='x')
plt.plot(steps_model2, val_loss_model2, label='Pitch + Time Model- Val Loss', marker='x')

# Add labels and legend
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Steps')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for all configurations
steps = [0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 4999]

# Configuration 1
train_loss_1 = [2.8827, 0.7742, 0.6977, 0.6402, 0.5957, 0.5335, 0.4597, 0.3777, 0.3093, 0.2536, 0.2105]
val_loss_1 = [2.8571, 0.7768, 0.7057, 0.6689, 0.6812, 0.7143, 0.7734, 0.8592, 0.9745, 1.0628, 1.1604]

# Configuration 2
train_loss_2 = [2.8605, 0.9055, 0.8383, 0.8017, 0.7762, 0.7594, 0.7463, 0.7339, 0.7225, 0.7143, 0.7038]
val_loss_2 = [2.8513, 0.8906, 0.8292, 0.7960, 0.7824, 0.7738, 0.7661, 0.7624, 0.7569, 0.7569, 0.7546]

# Configuration 3
train_loss_3 = [2.6619, 0.7925, 0.7286, 0.6547, 0.5731, 0.5032, 0.4345, 0.3598, 0.2902, 0.2352, 0.1998]
val_loss_3 = [2.6656, 0.7880, 0.7554, 0.7099, 0.6711, 0.6704, 0.7164, 0.7963, 0.8760, 0.9552, 1.0416]

# Plotting Training and Validation Loss
plt.figure(figsize=(10, 6))
plt.plot(steps, train_loss_1, 'o-', label="Config 1 - Train Loss", markersize=5)
plt.plot(steps, val_loss_1, 's-', label="Config 1 - Val Loss", markersize=5)
plt.plot(steps, train_loss_2, '^-', label="Config 2 - Train Loss", markersize=5)
plt.plot(steps, val_loss_2, 'd-', label="Config 2 - Val Loss", markersize=5)
plt.plot(steps, train_loss_3, 'x-', label="Config 3 - Train Loss", markersize=5)
plt.plot(steps, val_loss_3, 'p-', label="Config 3 - Val Loss", markersize=5)

plt.xlabel("Steps")
plt.ylabel("Loss")
plt.title("Training and Validation Loss for All Configurations")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for the first model
steps_model1 = [0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 4999]
train_loss_model1 = [3.6372, 0.7379, 0.6986, 0.6649, 0.6281, 0.5716, 0.5079, 0.3915, 0.2875, 0.2145, 0.1740]
val_loss_model1 = [3.6395, 0.8801, 0.8312, 0.8050, 0.7894, 0.7601, 0.7447, 0.7317, 0.6863, 0.6150, 0.5540]

# Data for the second model
steps_model2 = [0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 4999]
train_loss_model2 = [2.8827, 0.7742, 0.6977, 0.6402, 0.5957, 0.5335, 0.4597, 0.3777, 0.3093, 0.2536, 0.2105]
val_loss_model2 = [2.8571, 0.7768, 0.7057, 0.6689, 0.6812, 0.7143, 0.7734, 0.8592, 0.9745, 1.0628, 1.1604]

# Plotting
plt.figure(figsize=(6, 3))

# Model 1
plt.plot(steps_model1, train_loss_model1, 'o-', label="Octave Expansions Train Loss", markersize=5)
plt.plot(steps_model1, val_loss_model1, 's-', label="Octave Expansions Val Loss", markersize=5)

# Model 2
plt.plot(steps_model2, train_loss_model2, '^-', label="Inversions Train Loss", markersize=5)
plt.plot(steps_model2, val_loss_model2, 'd-', label="Inversions Val Loss", markersize=5)

# Labels and Title
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.title("Training and Validation Loss for Model trained on Octave Expansions and Inversions Datasets")
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for perplexity values
models = ["Base Dataset", "Octave Expansion", "Inversions"]
perplexity = [1.77, 1.236, 1.356]

# Plotting
plt.figure(figsize=(6, 3))
plt.bar(models, perplexity, color=['blue', 'orange', 'green'], alpha=0.7)

# Labels and Title
plt.xlabel("Datasets")
plt.ylabel("Perplexity")
plt.title("Perplexity Values of Model trained on different datasets")

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for perplexity values
models = ["Before  Changes", "After Changes"]
perplexity = [1.3005, 1.0036]

# Plotting
plt.figure(figsize=(6, 3))
plt.bar(models, perplexity, color=['blue', 'orange'], alpha=0.7)

# Labels and Title
plt.xlabel("Model")
plt.ylabel("Perplexity")
plt.title("Perplexity Values of Model before and after Architectural changes")

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Inversions-Before Changes (Replaced with Third Configuration)
steps_before = [0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 4999]
train_loss_before = [2.6619, 0.7925, 0.7286, 0.6547, 0.5731, 0.5032, 0.4345, 0.3598, 0.2902, 0.2352, 0.1998]
val_loss_before = [2.6656, 0.7880, 0.7554, 0.7099, 0.6711, 0.6704, 0.7164, 0.7963, 0.8760, 0.9552, 1.0416]

# Data for Inversions-After Changes
steps_after = [0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 4999]
train_loss_after = [2.9802, 0.0040, 0.0037, 0.0038, 0.0037, 0.0036, 0.0036, 0.0035, 0.0035, 0.0036, 0.0035]
val_loss_after = [2.9828, 0.0041, 0.0038, 0.0037, 0.0037, 0.0036, 0.0037, 0.0035, 0.0035, 0.0035, 0.0034]

# Plotting
plt.figure(figsize=(8, 5))

# Inversions-Before Changes (Third Configuration)
plt.plot(steps_before, train_loss_before, '^-', label="Inversions-Before Changes Train Loss", markersize=5)
plt.plot(steps_before, val_loss_before, 'd-', label="Inversions-Before Changes Val Loss", markersize=5)

# Inversions-After Changes
plt.plot(steps_after, train_loss_after, 'o-', label="Inversions-After Changes Train Loss", markersize=5)
plt.plot(steps_after, val_loss_after, 's-', label="Inversions-After Changes Val Loss", markersize=5)

# Labels and Title
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.title("Training and Validation Loss for Inversions-Before and After Architectural Changes")
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
import numpy as np

# Perplexity values for the three configurations
configs = ["Config 1", "Config 2", "Config 3"]
perplexity = [1.356, 2.04, 1.3005]

# Bar plot
plt.figure(figsize=(8, 5))
x = np.arange(len(configs))
plt.bar(x, perplexity, color=['skyblue', 'orange', 'green'], alpha=0.8)
plt.xticks(x, configs)
plt.xlabel("Configurations")
plt.ylabel("Perplexity")
plt.title("Perplexity Values for All Configurations")
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Adding values on top of bars
for i, value in enumerate(perplexity):
    plt.text(i, value + 0.05, f"{value:.3f}", ha='center')

plt.show()
